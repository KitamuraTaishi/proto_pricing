# %%
from scripts import pricing_ai

# %%
df = pricing_ai.get_data('sql/stock_id_all_info.sql')

# %%
df
# Out:
#                      stock_id    max_date            stock_id_1  n_car_cd  \
# 0        0601046A30191224W002  2020-01-02  0601046A30191224W002  10152046
# 1        0840039A20191116Q020  2020-01-02  0840039A20191116Q020  10501519
# 2        0551625A30191201W004  2020-01-03  0551625A30191201W004  10501012
# 3        0602142A30191227W001  2020-01-03  0602142A30191227W001  10202029
# 4        0507811A20191204J001  2020-01-03  0507811A20191204J001  10251029
# ...                       ...         ...                   ...       ...
# 1297402  1200357A30210424W003  2021-08-27  1200357A30210424W003  10552026
# 1297403  1200357A30210424W003  2021-09-23  1200357A30210424W003  10552026
# 1297404  1020510A30211009W001  2021-10-13  1020510A30211009W001  10552026
# 1297405  0620047A30211015W005  2021-10-23  0620047A30211015W005  10552026
# 1297406  0903895A30211216W004  2021-12-24  0903895A30211216W004  10552026
#
#         n_p_car_nm_n  katashiki  n_p_grade_id absyear  n_p_katashiki_id  \
# ...

# %%
df = df.drop(columns=['option_values', 'p_seibi_price'])

# %%
int(1.00000000001e63)
# Out:
# 1000000000010000017435987313219048989940031676666281242614824960
